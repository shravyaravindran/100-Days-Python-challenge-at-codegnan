# %%
s="CODEGNAN"

# %%
print(s)
# Out:
# CODEGNAN

# %% [markdown]
# # string operations
# ## string operations
# ### string operations
# #### string operations
# - string concatenation - (+)
# - string repeate - (*)

# %%
# concatenation
s1="Code"
s2="Gnan"
s3= s1 +" " +s2
print(s3)
# Out:
# Code Gnan

# %%
print(s1+s1+s1+s1)
# Out:
# CodeCodeCodeCode

# %%
# update 'c' with 'z'
s="codegnan"
print(s[0])
print('z' + s[1:])
x='z' +s[1:]
print(x,s) # codegnan or zodegnan
# Out:
# c
# zodegnan
# zodegnan codegnan

# %%
print('code'+ '3')
# Out:
# code3

# %%
#string repete
s="CodeGnan "
print( s * 3)
# Out:
# CodeGnan CodeGnan CodeGnan

# %% [markdown]
# ### String functions
# - case conversions functions -lower(),upper(),title(),swapcase(),capatilize()

# %%
s= "I am python BatcH studenT \n hello"
print(s.lower())
print(s.upper())
print(s.title())
print(s.swapcase())
print(s.capitalize())
# Out:
# i am python batch student
# I AM PYTHON BATCH STUDENT
# I Am Python Batch Student
# i AM PYTHON bATCh STUDENt
# I am python batch student

# %%
# sub string index finding
#find()
s= "I am python batcH studenT"
print(s.find("t"))
print(s.find("t",10))#it will check 10th position
print(s.find("z"))
print(s.index('t'))
print(s.find('Z'))
# Out:
# 7
# 14
# -1
# 7
# -1

# %%
#strip() - it removes the white space
s= "          codegnan         "
print(s)
print(s.strip())
print(s.lstrip())
print(s.rstrip())
# Out:
#           codegnan
# codegnan
# codegnan
#           codegnan

# %%
#splist(sep) - it returns the list of substring and it 
s = "@@@@@@codegnan@@@@@@"
print(s)
print(s.strip('@'))
print(s.lstrip())
print(s.rstrip('@'))
# Out:
# @@@@@@codegnan@@@@@@
# codegnan
# @@@@@@codegnan@@@@@@
# @@@@@@codegnan

# %%
s="I am python BatcH studenT"
print(s.split())
# Out:
# ['I', 'am', 'python', 'BatcH', 'studenT']

# %%
#Case checking functions
s1= "CODE"
s2 ="gnan"
s3="123"
s4="abc123"
s5="Codegnan"
print(s1.isupper())
print(s2.isupper())
print(s1.islower())
print(s2.islower())
print(s3.isdigit())
print(s4.isalnum())
print(s4.isdigit())
print(s4.isalnum())
print(s5.isalpha())
# Out:
# True
# False
# False
# True
# True
# True
# False
# True
# True

# %%
#username validation
      - minimum length - 8
      - atleast one uppercase and one lowercase letter
      - special charater ("_","@")
      - it contain digits
#password validation

# %%
# username and password validator using case check functions
#username
username=input("Enter username: ")
if len(username) >=8 and username[0].isalpha() : 
    for char in username:
        if char.isupper():
            has_upper=True
        elif char.islower():
            has_lower=True
        elif char.isdigit():
            has_digit=True
        elif char in ["_","@"]:
            has_special=True
    if has_upper and has_lower and has_digit and has_special:
        print("Username is valid!")
    else:
        print("Username is not valid!")
else:
    print("Username is not valid!")
#password 
password=input("Enter password: ")
if len(password) >=8 and password[0].isalpha() : 
    for char in password:
        if char.isupper():
            has_upper=True
        elif char.islower():
            has_lower=True
        elif char.isdigit():
            has_digit=True
        elif char in ["_","@"]:
            has_special=True
    if has_upper and has_lower and has_digit and has_special:
        print("Password is valid!")
    else:
        print("Password is not valid!")
else:
    print("Password is not valid!")
# Out:
# Enter username:  Shravya@123
# Username is valid!
# Enter password:  Shravya@31102004
# Password is valid!

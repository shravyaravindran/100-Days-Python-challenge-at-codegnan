# %%
def add_three_numbers(a, b, c):
    return a + b + c

# Taking input from the user
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

# Function call
result = add_three_numbers(num1, num2, num3)

print("Sum of three numbers is:", result)
# Out:
# Enter first number:  2
# Enter second number:  4
# Enter third number:  5
# Sum of three numbers is: 11

# %% [markdown]
# ### Types of Arguments
# 1.positional Arguments 2.keyword Arguments 3.Default Arguments 4.variable lenghts positional of agrument 5.variable lenght of keyword arguments

# %%
# default arguments  
def add(a,b):
    return a+b
print(add(10,2))
# Out:
# 12

# %%
# default arguments
def add(a,b,c=0,d=0):
    return a+b+c+d 
print(add(1,2))
print(add(1,2,3))
print(add(1,2,4))
# Out:
# 3
# 6
# 7

# %%
# multiplication of numbers using default arguments
def mul(a,b,c=1,d=1):
    return a*b*c*d 
print(mul(1,2,3,4))
print(mul(1,2,3))
print(mul(1,2,4))
print(mul(1,2))
# Out:
# 24
# 6
# 8
# 2

# %%
# variable length of positional arguments
def add(a,*args):
    print(a)
    print(args)
add(1,2,3,4,5,6)
# Out:
# 1
# (2, 3, 4, 5, 6)

# %%
# variable length of positional arguments
a,*b,c=10,20,30,40,50
print(a)
print(b)
print(c)
# Out:
# 10
# [20, 30, 40]
# 50

# %%
a,*b=10,20,30,40,50
print(a)
print(b)
# Out:
# 10
# [20, 30, 40, 50]

# %%
# variable length of positional arguments
def add(a,*args):
    print(a)
    print(args)
    s=0
    for num in args:
        s+=num
    return s
print(add(1,2,3,9))
# Out:
# 1
# (2, 3, 9)
# 14

# %% [markdown]
# ### List of operations
# - concatination
# - repeate

# %%
#List concatination
l1=[1,2,3]
l2=[4,5,6]
l3=l1+l2
print(l3)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# List repeate
l1 = [1, 3, 2]
l2 = [3, 6, 8]
l3 = l1 * 10
print(l3)
# Out:
# [1, 3, 2, 1, 3, 2, 1, 3, 2, 1, 3, 2, 1, 3, 2, 1, 3, 2, 1, 3, 2, 1, 3, 2, 1, 3, 2, 1, 3, 2]

# %%
#List repeatation 
l1=[1,2,3]
print(l1*2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
# empty list representation
l1 = []
l2 = list()
print (type(l2))
print(len(l2),len(l2))
# Out:
# <class 'list'>
# 0 0

# %% [markdown]
# ### list operations
# -adding element functions

# %%
#add one element to the list
lst=[1,2,3]
lst.append(10)
print(lst)
# Out:
# [1, 2, 3, 10]

# %%
#add one element to the list
lst=[1,2,3]
print(lst.append(10))
print(lst)
# Out:
# None
# [1, 2, 3, 10]

# %%
# list functions 
lst = [1,2,3,4]
print(lst.append (10))
print(lst)
# Out:
# None
# [1, 2, 3, 4, 10]

# %%
# list functions 
lst = [1,2,3,4]
lst.append  ([10,20,30])
print(lst)
# Out:
# [1, 2, 3, 4, [10, 20, 30]]

# %%
lst=[1,2,3]
print(lst.append([1,2,3]))
print(lst)
# Out:
# None
# [1, 2, 3, [1, 2, 3]]

# %%
# add 100 elements to the end of list
lst = [1,2,3]
print(lst + [100])
# Out:
# [1, 2, 3, 100]

# %%
lst=[1,2,3]
print(lst.extend([1,2,3]))
print(lst)
# Out:
# None
# [1, 2, 3, 1, 2, 3]

# %%
lst=[1,2,3]
lst.insert(1,900)
lst.insert(1,9)
print(lst)
lst.insert(100,9)
print(lst)
# Out:
# [1, 9, 900, 2, 3]
# [1, 9, 900, 2, 3, 9]

# %% [markdown]
# ### removing element functions

# %%
lst = [1,2,3,4]
print(lst.pop())
print(lst.pop(2))
# Out:
# 4
# 3

# %%
lst=[1,2,3,4]
print(lst.pop())
## print(lst.pop(3))   #indedx out of range
# Out:
# 4

# %%
lst = [1,2,3,4,5,6,7]
lst.remove(2)
lst.remove(3)
print(lst)
# Out:
# [1, 4, 5, 6, 7]

# %%
lst=[1,2,3,2,4,6,7,6,6,8]
del lst[2]
print(lst)
del lst[4:7]
print(lst)
# Out:
# [1, 2, 2, 4, 6, 7, 6, 6, 8]
# [1, 2, 2, 4, 6, 8]

# %%
lst = [1,2,3,3,5,6,7,7,9]
print(lst.count(3))
print(lst.count(8))
# Out:
# 2
# 0

# %%
lst = [1,2,3,4,5,6,7,8,9]
print(lst.index(3))
print(lst.index(8))
# Out:
# 2
# 7

# %%
lst=[1,2,3,2,2,2,4,6,7,6,6,8]
print(lst.index(2,5))     #it starts  to find the index of element 2 from the index 5
print(lst.index(8))       #print(lst.index(84))   - we get the error
print(lst.index(2,lst.index(2)+1))
# Out:
# 5
# 11
# 3

# %%
lst = [1,2,3,3,4,3,4,2,5]
lst.sort()
print(lst)
# Out:
# [1, 2, 2, 3, 3, 3, 4, 4, 5]

# %%
lst=[1,2,3,9,8,0,2,2,2,4,6,7,6,6,8]
lst.sort()
print(lst)
lst.sort(reverse=True)
print(lst)
# Out:
# [0, 1, 2, 2, 2, 2, 3, 4, 6, 6, 6, 7, 8, 8, 9]
# [9, 8, 8, 7, 6, 6, 6, 4, 3, 2, 2, 2, 2, 1, 0]

# %%
min(['a','l','p','2'])   
min(['a','l','p'])
# Out:
# 'a'

# %%
# convert list of numbers into even list and odd list
lst = list(map(int, input().split()))
even_list = []
odd_list = []
for num in lst:
    # check the numbers os even or odd
    if num % 2 == 0:
        even_list.append(num)
    else:
        odd_list.append(num)
print("Even list:",even_list)
print("Odd list:",odd_list)
# Out:
#  1 2 3 4 5 6 7 8 9
# Even list: [2, 4, 6, 8]
# Odd list: [1, 3, 5, 7, 9]

# %%
#take the elements into the  list and and check the number even or odd if it even add into the even list and if it is odd add in to the odd list
l1=list(map(int,input().split()))
even=[]
odd=[]
for i in l1:
    if i%2:
       odd.append(i)
    else:
       even.append(i)
print(odd)
print(even)
# Out:
#  1 2 3 4 5 6 7 8 9
# [1, 3, 5, 7, 9]
# [2, 4, 6, 8]

# %%
def check(l1):
    for i in l1:
        if i%2:
           return odd.append(i)
        else:
           return even.append(i)


l1=list(map(int,input().split()))
even=[]
odd=[]
print(odd)
print(even)
# Out:
#  22
# []
# []

# %%
# marks analyser
#in list contains students marks, in that, find the pass percentage and fail percentage
#pass marks is 35(+)
#fail is below 35 (-)
marks=list(map(int, input("enter marks:").split()))
def marks_analyser(marks):
    avg = sum(marks)/len (marks)
    if avg >= 35:
        return "pass"
    else:
        return "fail"
print(marks_analyser(marks))
# Out:
# enter marks: 38
# pass
